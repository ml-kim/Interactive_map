# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import folium 
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/seoul-apt-price-withloc/merged_dataset_2019_2020.csv

# %% [markdown]
# ### Intro
# * In this note, I create interactive maps using a data set that includes the prices of seoul apartments.
# > * These maps show the distribution of APT complexes whose transaction volumes are greater than certain levels and their average prices.
# * The package used: `panda` and `folium`

# %% [markdown]
# ### Import data
#
# * We use a data set that includes transaction prices of seoul apartments from Dec 2019 to Dec 2020 and their location information (latitude and longitude).

# %%
# import data
dat = pd.read_csv("../input/seoul-apt-price-withloc/merged_dataset_2019_2020.csv")
dat.head()
# Out:
#                                             address   size  year  month  \
# 0  서울특별시 강남구 개포동\t655-2\t0655\t0002\t개포2차현대아파트(220)  77.75  2020      6
# 1  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  54.98  2020      2
# 2  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  79.97  2020      6
# 3  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  79.97  2020      6
# 4  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  79.97  2020      6
#
#             price  floor  const_year        lat         lng
# 0         149,500      4        1988  37.482630  127.051104
# 1         144,000      4        1987  37.476658  127.056909
# 2         162,750      4        1987  37.476658  127.056909
# 3         160,000      5        1987  37.476658  127.056909
# 4         150,000      2        1987  37.476658  127.056909

# %% [markdown]
# ### Process data
#
#
# 1. Define the type of `price` column properly.
# 2. Calculate average price for each APT complex, year and month.
# 3. Calculate transaction volume for each APT complex and reference periods (for last 3months/6months/1year).

# %%
# change the type of price from object to float64
for line in range(0, len(dat)):
    dat["price"][line]= float(dat["price"][line].replace(",",""))

dat["price"] = dat["price"].astype("float64")
dat.dtypes
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# address        object
# size          float64
# year            int64
# month           int64
# price         float64
# floor           int64
# const_year      int64
# lat           float64
# lng           float64
# dtype: object

# %%
dat.head()
# Out:
#                                             address   size  year  month  \
# 0  서울특별시 강남구 개포동\t655-2\t0655\t0002\t개포2차현대아파트(220)  77.75  2020      6
# 1  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  54.98  2020      2
# 2  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  79.97  2020      6
# 3  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  79.97  2020      6
# 4  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  79.97  2020      6
#
#       price  floor  const_year        lat         lng
# 0  149500.0      4        1988  37.482630  127.051104
# 1  144000.0      4        1987  37.476658  127.056909
# 2  162750.0      4        1987  37.476658  127.056909
# 3  160000.0      5        1987  37.476658  127.056909
# 4  150000.0      2        1987  37.476658  127.056909

# %%
# create yearmon column: year + month
def create_yearmon(row):
    x= str(row["year"])+"-"+ str(row["month"])
    return x
dat['yearmon'] = dat.apply(lambda row: create_yearmon(row), axis = 1)
dat.head()
# Out:
#                                             address   size  year  month  \
# 0  서울특별시 강남구 개포동\t655-2\t0655\t0002\t개포2차현대아파트(220)  77.75  2020      6
# 1  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  54.98  2020      2
# 2  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  79.97  2020      6
# 3  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  79.97  2020      6
# 4  서울특별시 강남구 개포동\t658-1\t0658\t0001\t개포6차우성아파트1동~8동  79.97  2020      6
#
#       price  floor  const_year        lat         lng yearmon
# 0  149500.0      4        1988  37.482630  127.051104  2020-6
# 1  144000.0      4        1987  37.476658  127.056909  2020-2
# 2  162750.0      4        1987  37.476658  127.056909  2020-6
# 3  160000.0      5        1987  37.476658  127.056909  2020-6
# 4  150000.0      2        1987  37.476658  127.056909  2020-6

# %%
# calculate average transaction price for each apt complex
def calcul_avgprice(year0, month0, year1, month1):
    dat1= dat[(dat["year"]>=year0) & (dat["month"]>= month0)] 
    dat1 = dat1[(dat1["year"]<=year1) & (dat1["month"]<= month1)]
    dat1["avgprice"]= dat1.groupby("address")["price"].transform("mean")
    return dat1


## calculate average transaction price for each apt complex and yearmon
# dat["avgprice"] = dat.groupby(["address", "yearmon"])["price"].transform("mean")
## calculate average transaction price for each apt complex and year
# dat["yr_avgprice"] = dat.groupby(["address", "year"])["price"].transform("mean")

# %%
# calculate transaction volume for each apt complex and periods (3months/6months/1year)
def count_past_sales(series, intval = "90D"):
    series2 = pd.to_datetime(series)
    sale_time = pd.Series(series2.index, index=series2, name='count_sales_this_month').sort_index() # exchange the positions of index and values
    count_sales = sale_time.rolling(intval, min_periods=1).count()
    count_sales = count_sales.groupby(count_sales.index.month).transform('last')
    return count_sales

# transaction volume for last 3 months/6months/1year
aa=dat.groupby('address')["yearmon"].apply(count_past_sales)
bb=dat.groupby('address')["yearmon"].apply(lambda series: count_past_sales(series, intval = "180D"))
cc=dat.groupby('address')["yearmon"].apply(lambda series: count_past_sales(series, intval = "365D"))

# put index
aa.index=dat.sort_values(by=['address','year', "month"]).index
bb.index=dat.sort_values(by=['address','year', "month"]).index
cc.index=dat.sort_values(by=['address','year', "month"]).index

dat['num_sales_last_3months']=aa
dat['num_sales_last_6months']=bb
dat['num_sales_last_12months']=cc

# %%
# drop observations with inappropriate location info
dat.drop(dat[dat["lng"].isnull() == True].index,axis = 0, inplace = True)
dat.drop(dat[dat["lat"].isnull() == True].index,axis = 0, inplace = True)

# %%
# create a column: "color" using price information
def colouring(row, pr_col="avgprice"):
    if (row[pr_col] > 0) and (row[pr_col] <= 50000): # less than $500k 
        return "beige"
    elif (row[pr_col] > 50000) and (row[pr_col] <= 100000): # more than $500k and less than $1m
        return "orange"
    elif (row[pr_col] > 100000) and (row[pr_col] <= 150000): # more than $1m and less than $1.5m
        return "red"
    elif (row[pr_col] > 150000) and (row[pr_col] <= 200000): # more than $1.5m and less than $2m
        return "darkred"
    return "darkpurple"
#dat["color"] = dat.apply(colouring, axis = 1)
#dat["yr_color"] = dat.apply(lambda row: colouring(row, pr_col = "yr_avgprice"), axis = 1)

#dat.head()

# %% [markdown]
# ### Default setting for an interactive map

# %%
# define a map
my_map = folium.Map(
    location = [37.544294, 127.0016985], 
    width="%40",
    height="%35",
    zoom_start= 12)

# %% [markdown]
# ### Create interactive maps

# %%
# Function for making a subdat set
def mapping(nums = "num_sales_last_3months", min_transvol = 10, yr0 = 2020, yr1 = 2020, mon0=1, mon1 = 12):
    # calculate avg prices per APT complex 
    dat = calcul_avgprice(yr0, mon0, yr1, mon1)
    # define color
    dat["color"] = dat.apply(colouring, axis = 1)
    subdat = dat[(dat[nums]>min_transvol)]
    subdat = subdat.drop_duplicates(subset=['address'])
    for _, apt in subdat.iterrows():
        folium.Marker(
        location = [apt["lat"], apt["lng"]],
        popup = apt["address"],
        tooltip = apt["avgprice"],
        icon = folium.Icon(color = apt["color"])).add_to(my_map)
    return(my_map)

# %% [markdown]
# * The interactive map below shows all apartment complexes whose transaction voloume were more than 50 for `last 3 months` as of 2020
# * The colour of icons shows the level of average prices of the apartment complexes.
#
#  > 1. beige: less than $\$500k$
#  > 2. orange:  from $\$500k$ to $\$1m$
#  > 3. red:  from $\$1m$ to $\$1.5m$
#  > 4. darkred: from $\$1.5m$ to $\$2m$
#  > 5. darkpurple: more than $\$2m$

# %%
mapping(min_transvol =  50)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b960e66e122c7ad0f701191986365c5 {
#                     position: relative;
#                     width: 40.0%;
#                     height: 35.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b960e66e122c7ad0f701191986365c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6b960e66e122c7ad0f701191986365c5 = L.map(
#                 &quot;map_6b960e66e122c7ad0f701191986365c5&quot;,
#                 {
#                     center: [37.544294, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53024c281b0aafd8e8d33480b08c0c2e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var marker_c73b4bfb228f112089346e388c8253b1 = L.marker(
#                 [37.4974576, 127.0653265],
#                 {}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var icon_560ee86d59b29d8f2460fa139e54cb1c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c73b4bfb228f112089346e388c8253b1.setIcon(icon_560ee86d59b29d8f2460fa139e54cb1c);
#
#
#         var popup_2f6a552f7dcc78079e4016248bddb308 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_350c13856b058cdc41f92615c0316688 = $(`&lt;div id=&quot;html_350c13856b058cdc41f92615c0316688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강남구 대치동	316	0316	0000	은마&lt;/div&gt;`)[0];
#             popup_2f6a552f7dcc78079e4016248bddb308.setContent(html_350c13856b058cdc41f92615c0316688);
#
#
#         marker_c73b4bfb228f112089346e388c8253b1.bindPopup(popup_2f6a552f7dcc78079e4016248bddb308)
#         ;
#
#
#
#
#             marker_c73b4bfb228f112089346e388c8253b1.bindTooltip(
#                 `&lt;div&gt;
#                      199480.95238095237
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_822246b6d5295fc43b8ee00e4754c0c7 = L.marker(
#                 [37.4737864, 127.1017461],
#                 {}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var icon_5c5e745ed097c0a492c9a5e73870a43f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_822246b6d5295fc43b8ee00e4754c0c7.setIcon(icon_5c5e745ed097c0a492c9a5e73870a43f);
#
#
#         var popup_d492cda4f8ce4598375baad2e0a2265a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_045636739c1e741e44988c424d42041f = $(`&lt;div id=&quot;html_045636739c1e741e44988c424d42041f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강남구 자곡동	602	0602	0000	엘에이치강남아이파크&lt;/div&gt;`)[0];
#             popup_d492cda4f8ce4598375baad2e0a2265a.setContent(html_045636739c1e741e44988c424d42041f);
#
#
#         marker_822246b6d5295fc43b8ee00e4754c0c7.bindPopup(popup_d492cda4f8ce4598375baad2e0a2265a)
#         ;
#
#
#
#
#             marker_822246b6d5295fc43b8ee00e4754c0c7.bindTooltip(
#                 `&lt;div&gt;
#                      92253.91304347826
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6fa486336de5bceab4336e030acb1c0a = L.marker(
#                 [37.5594375, 127.1476045],
#                 {}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var icon_d9f4ae11628b58de14c871632b700e40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6fa486336de5bceab4336e030acb1c0a.setIcon(icon_d9f4ae11628b58de14c871632b700e40);
#
#
#         var popup_ef960e74d330fb9c3f524716b182549f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2a0e2a8f6ad1159388b98dc8a64f9b1a = $(`&lt;div id=&quot;html_2a0e2a8f6ad1159388b98dc8a64f9b1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강동구 고덕동	688	0688	0000	고덕래미안 힐스테이트아파트&lt;/div&gt;`)[0];
#             popup_ef960e74d330fb9c3f524716b182549f.setContent(html_2a0e2a8f6ad1159388b98dc8a64f9b1a);
#
#
#         marker_6fa486336de5bceab4336e030acb1c0a.bindPopup(popup_ef960e74d330fb9c3f524716b182549f)
#         ;
#
#
#
#
#             marker_6fa486336de5bceab4336e030acb1c0a.bi

# %% [markdown]
# * The interactive map below shows all apartment complexes whose transaction voloume were more than 50 for `last 6 months` as of 2020

# %%
mapping(nums="num_sales_last_6months", min_transvol =  50)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b960e66e122c7ad0f701191986365c5 {
#                     position: relative;
#                     width: 40.0%;
#                     height: 35.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b960e66e122c7ad0f701191986365c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6b960e66e122c7ad0f701191986365c5 = L.map(
#                 &quot;map_6b960e66e122c7ad0f701191986365c5&quot;,
#                 {
#                     center: [37.544294, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53024c281b0aafd8e8d33480b08c0c2e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var marker_c73b4bfb228f112089346e388c8253b1 = L.marker(
#                 [37.4974576, 127.0653265],
#                 {}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var icon_560ee86d59b29d8f2460fa139e54cb1c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c73b4bfb228f112089346e388c8253b1.setIcon(icon_560ee86d59b29d8f2460fa139e54cb1c);
#
#
#         var popup_2f6a552f7dcc78079e4016248bddb308 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_350c13856b058cdc41f92615c0316688 = $(`&lt;div id=&quot;html_350c13856b058cdc41f92615c0316688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강남구 대치동	316	0316	0000	은마&lt;/div&gt;`)[0];
#             popup_2f6a552f7dcc78079e4016248bddb308.setContent(html_350c13856b058cdc41f92615c0316688);
#
#
#         marker_c73b4bfb228f112089346e388c8253b1.bindPopup(popup_2f6a552f7dcc78079e4016248bddb308)
#         ;
#
#
#
#
#             marker_c73b4bfb228f112089346e388c8253b1.bindTooltip(
#                 `&lt;div&gt;
#                      199480.95238095237
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_822246b6d5295fc43b8ee00e4754c0c7 = L.marker(
#                 [37.4737864, 127.1017461],
#                 {}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var icon_5c5e745ed097c0a492c9a5e73870a43f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_822246b6d5295fc43b8ee00e4754c0c7.setIcon(icon_5c5e745ed097c0a492c9a5e73870a43f);
#
#
#         var popup_d492cda4f8ce4598375baad2e0a2265a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_045636739c1e741e44988c424d42041f = $(`&lt;div id=&quot;html_045636739c1e741e44988c424d42041f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강남구 자곡동	602	0602	0000	엘에이치강남아이파크&lt;/div&gt;`)[0];
#             popup_d492cda4f8ce4598375baad2e0a2265a.setContent(html_045636739c1e741e44988c424d42041f);
#
#
#         marker_822246b6d5295fc43b8ee00e4754c0c7.bindPopup(popup_d492cda4f8ce4598375baad2e0a2265a)
#         ;
#
#
#
#
#             marker_822246b6d5295fc43b8ee00e4754c0c7.bindTooltip(
#                 `&lt;div&gt;
#                      92253.91304347826
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6fa486336de5bceab4336e030acb1c0a = L.marker(
#                 [37.5594375, 127.1476045],
#                 {}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var icon_d9f4ae11628b58de14c871632b700e40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6fa486336de5bceab4336e030acb1c0a.setIcon(icon_d9f4ae11628b58de14c871632b700e40);
#
#
#         var popup_ef960e74d330fb9c3f524716b182549f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2a0e2a8f6ad1159388b98dc8a64f9b1a = $(`&lt;div id=&quot;html_2a0e2a8f6ad1159388b98dc8a64f9b1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강동구 고덕동	688	0688	0000	고덕래미안 힐스테이트아파트&lt;/div&gt;`)[0];
#             popup_ef960e74d330fb9c3f524716b182549f.setContent(html_2a0e2a8f6ad1159388b98dc8a64f9b1a);
#
#
#         marker_6fa486336de5bceab4336e030acb1c0a.bindPopup(popup_ef960e74d330fb9c3f524716b182549f)
#         ;
#
#
#
#
#             marker_6fa486336de5bceab4336e030acb1c0a.bi

# %% [markdown]
# * The interactive map below shows all apartment complexes whose transaction voloume were more than 50 for `last 12 months` as of 2020

# %%
mapping(nums="num_sales_last_12months", min_transvol =  50)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b960e66e122c7ad0f701191986365c5 {
#                     position: relative;
#                     width: 40.0%;
#                     height: 35.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b960e66e122c7ad0f701191986365c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6b960e66e122c7ad0f701191986365c5 = L.map(
#                 &quot;map_6b960e66e122c7ad0f701191986365c5&quot;,
#                 {
#                     center: [37.544294, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53024c281b0aafd8e8d33480b08c0c2e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var marker_c73b4bfb228f112089346e388c8253b1 = L.marker(
#                 [37.4974576, 127.0653265],
#                 {}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var icon_560ee86d59b29d8f2460fa139e54cb1c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c73b4bfb228f112089346e388c8253b1.setIcon(icon_560ee86d59b29d8f2460fa139e54cb1c);
#
#
#         var popup_2f6a552f7dcc78079e4016248bddb308 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_350c13856b058cdc41f92615c0316688 = $(`&lt;div id=&quot;html_350c13856b058cdc41f92615c0316688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강남구 대치동	316	0316	0000	은마&lt;/div&gt;`)[0];
#             popup_2f6a552f7dcc78079e4016248bddb308.setContent(html_350c13856b058cdc41f92615c0316688);
#
#
#         marker_c73b4bfb228f112089346e388c8253b1.bindPopup(popup_2f6a552f7dcc78079e4016248bddb308)
#         ;
#
#
#
#
#             marker_c73b4bfb228f112089346e388c8253b1.bindTooltip(
#                 `&lt;div&gt;
#                      199480.95238095237
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_822246b6d5295fc43b8ee00e4754c0c7 = L.marker(
#                 [37.4737864, 127.1017461],
#                 {}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var icon_5c5e745ed097c0a492c9a5e73870a43f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_822246b6d5295fc43b8ee00e4754c0c7.setIcon(icon_5c5e745ed097c0a492c9a5e73870a43f);
#
#
#         var popup_d492cda4f8ce4598375baad2e0a2265a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_045636739c1e741e44988c424d42041f = $(`&lt;div id=&quot;html_045636739c1e741e44988c424d42041f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강남구 자곡동	602	0602	0000	엘에이치강남아이파크&lt;/div&gt;`)[0];
#             popup_d492cda4f8ce4598375baad2e0a2265a.setContent(html_045636739c1e741e44988c424d42041f);
#
#
#         marker_822246b6d5295fc43b8ee00e4754c0c7.bindPopup(popup_d492cda4f8ce4598375baad2e0a2265a)
#         ;
#
#
#
#
#             marker_822246b6d5295fc43b8ee00e4754c0c7.bindTooltip(
#                 `&lt;div&gt;
#                      92253.91304347826
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6fa486336de5bceab4336e030acb1c0a = L.marker(
#                 [37.5594375, 127.1476045],
#                 {}
#             ).addTo(map_6b960e66e122c7ad0f701191986365c5);
#
#
#             var icon_d9f4ae11628b58de14c871632b700e40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6fa486336de5bceab4336e030acb1c0a.setIcon(icon_d9f4ae11628b58de14c871632b700e40);
#
#
#         var popup_ef960e74d330fb9c3f524716b182549f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2a0e2a8f6ad1159388b98dc8a64f9b1a = $(`&lt;div id=&quot;html_2a0e2a8f6ad1159388b98dc8a64f9b1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강동구 고덕동	688	0688	0000	고덕래미안 힐스테이트아파트&lt;/div&gt;`)[0];
#             popup_ef960e74d330fb9c3f524716b182549f.setContent(html_2a0e2a8f6ad1159388b98dc8a64f9b1a);
#
#
#         marker_6fa486336de5bceab4336e030acb1c0a.bindPopup(popup_ef960e74d330fb9c3f524716b182549f)
#         ;
#
#
#
#
#             marker_6fa486336de5bceab4336e030acb1c0a.bi
