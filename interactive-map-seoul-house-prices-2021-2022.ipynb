# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import folium 
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/seoul-apt-info/seoul_apt_info.csv

# %% [markdown]
# ### Intro
# * In this note, I create interactive maps using a data set that includes the prices of seoul apartments.
# > * These maps show the distribution of APT complexes whose transaction volumes are greater than certain levels and their average prices.
# * The package used: `panda` and `folium`

# %% [markdown]
# ### Import data
#
# * We use a data set that includes transaction prices of seoul apartments from Jan 2021 to May 2022 and their location information (latitude and longitude).

# %%
# import data
dat = pd.read_csv("../input/seoul-apt-info/seoul_apt_info.csv")
dat = dat.drop(["Unnamed: 0"], axis = 1)
dat.head()
# Out:
#                                 address   size  yearmon   price  floor  \
# 0  서울특별시 강남구 개포동 언주로 103 개포2차현대아파트(220)  77.75   202104  174000      9
# 1    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202105  195000      5
# 2    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202108  200000      3
# 3    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202109  220000      2
# 4    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202112  215000      3
#
#    const_year        lat         lng
# 0        1988  37.482630  127.051104
# 1        1987  37.476658  127.056909
# 2        1987  37.476658  127.056909
# 3        1987  37.476658  127.056909
# 4        1987  37.476658  127.056909

# %% [markdown]
# ### Process data
#
# 1. Calculate average price for each APT complex, year and month.
# 2. Calculate transaction volume for each APT complex and reference periods (for last 3months/6months/1year).

# %%
dat.dtypes
# Out:
# address        object
# size          float64
# yearmon         int64
# price           int64
# floor           int64
# const_year      int64
# lat           float64
# lng           float64
# dtype: object

# %%
def split_yr_mon(row):
    x = str(row["yearmon"])[0:4]
    x = int(x)
    return x
dat['year'] = dat.apply(lambda row: split_yr_mon(row), axis = 1)

# %%
dat.head()
# Out:
#                                 address   size  yearmon   price  floor  \
# 0  서울특별시 강남구 개포동 언주로 103 개포2차현대아파트(220)  77.75   202104  174000      9
# 1    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202105  195000      5
# 2    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202108  200000      3
# 3    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202109  220000      2
# 4    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202112  215000      3
#
#    const_year        lat         lng  year
# 0        1988  37.482630  127.051104  2021
# 1        1987  37.476658  127.056909  2021
# 2        1987  37.476658  127.056909  2021
# 3        1987  37.476658  127.056909  2021
# 4        1987  37.476658  127.056909  2021

# %%
def split_yr_mon2(row):
    x = str(row["yearmon"])[4:6]
    x = int(x)
    return x
dat['month'] = dat.apply(lambda row: split_yr_mon2(row), axis = 1)

# %%
dat.head()
# Out:
#                                 address   size  yearmon   price  floor  \
# 0  서울특별시 강남구 개포동 언주로 103 개포2차현대아파트(220)  77.75   202104  174000      9
# 1    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202105  195000      5
# 2    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202108  200000      3
# 3    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202109  220000      2
# 4    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202112  215000      3
#
#    const_year        lat         lng  year  month
# 0        1988  37.482630  127.051104  2021      4
# 1        1987  37.476658  127.056909  2021      5
# 2        1987  37.476658  127.056909  2021      8
# 3        1987  37.476658  127.056909  2021      9
# 4        1987  37.476658  127.056909  2021     12

# %%
dat.drop(["yearmon"], axis = 1, inplace = True)

# %%
# create yearmon column: year + month
def create_yearmon(row):
    x= str(row["year"])+"-"+ str(row["month"])
    return x
dat['yearmon'] = dat.apply(lambda row: create_yearmon(row), axis = 1)
dat.head()
# Out:
#                                 address   size   price  floor  const_year  \
# 0  서울특별시 강남구 개포동 언주로 103 개포2차현대아파트(220)  77.75  174000      9        1988
# 1    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97  195000      5        1987
# 2    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97  200000      3        1987
# 3    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97  220000      2        1987
# 4    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97  215000      3        1987
#
#          lat         lng  year  month  yearmon
# 0  37.482630  127.051104  2021      4   2021-4
# 1  37.476658  127.056909  2021      5   2021-5
# 2  37.476658  127.056909  2021      8   2021-8
# 3  37.476658  127.056909  2021      9   2021-9
# 4  37.476658  127.056909  2021     12  2021-12

# %%
# calculate average transaction price for each apt complex
def calcul_avgprice(year0, month0, year1, month1):
    dat1= dat[(dat["year"]>=year0) & (dat["month"]>= month0)] 
    dat1 = dat1[(dat1["year"]<=year1) & (dat1["month"]<= month1)]
    dat1["avgprice"]= dat1.groupby("address")["price"].transform("mean")
    return dat1


## calculate average transaction price for each apt complex and yearmon
# dat["avgprice"] = dat.groupby(["address", "yearmon"])["price"].transform("mean")
## calculate average transaction price for each apt complex and year
# dat["yr_avgprice"] = dat.groupby(["address", "year"])["price"].transform("mean")

# %%
# calculate transaction volume for each apt complex and periods (3months/6months/1year)
def count_past_sales(series, intval = "90D"):
    series2 = pd.to_datetime(series)
    sale_time = pd.Series(series2.index, index=series2, name='count_sales_this_month').sort_index() # exchange the positions of index and values
    count_sales = sale_time.rolling(intval, min_periods=1).count()
    count_sales = count_sales.groupby(count_sales.index.month).transform('last')
    return count_sales

# transaction volume for last 3 months/6months/1year
aa=dat.groupby('address')["yearmon"].apply(count_past_sales)
bb=dat.groupby('address')["yearmon"].apply(lambda series: count_past_sales(series, intval = "180D"))
cc=dat.groupby('address')["yearmon"].apply(lambda series: count_past_sales(series, intval = "365D"))

# put index
aa.index=dat.sort_values(by=['address','year', "month"]).index
bb.index=dat.sort_values(by=['address','year', "month"]).index
cc.index=dat.sort_values(by=['address','year', "month"]).index

dat['num_sales_last_3months']=aa
dat['num_sales_last_6months']=bb
dat['num_sales_last_12months']=cc

# %%
# drop observations with inappropriate location info
dat.drop(dat[dat["lng"].isnull() == True].index,axis = 0, inplace = True)
dat.drop(dat[dat["lat"].isnull() == True].index,axis = 0, inplace = True)

# %%
def assign_values(pr_col="avgprice"):
    if pr_col == "avgprice":
        return  0, 50000,100000,150000,200000
    elif pr_col in ["num_sales_last_3months", "num_sales_last_6months", "num_sales_last_12months"]:
        return 0,10,20,30,40
# create a column: "color" using price information
def colouring(row, pr_col="avgprice"):
    a0, a1, a2, a3, a4 = assign_values(pr_col)
    if (row[pr_col] > a0) and (row[pr_col] <= a1): # less than $500k 
        return "beige"
    elif (row[pr_col] > a1) and (row[pr_col] <= a2): # more than $500k and less than $1m
        return "orange"
    elif (row[pr_col] > a2) and (row[pr_col] <= a3): # more than $1m and less than $1.5m
        return "red"
    elif (row[pr_col] > a3) and (row[pr_col] <= a4): # more than $1.5m and less than $2m
        return "darkred"
    return "darkpurple"

# %% [markdown]
# ### Default setting for an interactive map

# %%
# define a map
def initialize_map():
    my_map = folium.Map(
        location = [37.544294, 127.0016985], 
        width="%40",
        height="%35",
        zoom_start= 12)
    return my_map

# %% [markdown]
# ### Create interactive maps

# %%
# Function for making a subdat set
def mapping(nums = "num_sales_last_3months", min_transvol = 10, color_col= "avgprice", yr0 = 2021, yr1 = 2022, mon0=1, mon1 = 5):
    # calculate avg prices per APT complex 
    dat = calcul_avgprice(yr0, mon0, yr1, mon1)
    # define color   
    dat["color"] = dat.apply(lambda row: colouring(row, pr_col = color_col), axis = 1)
    subdat = dat[(dat[nums]>min_transvol)]
    subdat = subdat.sort_values(by = ["address", "year", "month"])
    subdat["v_last_vol"] = subdat.groupby("address")[nums].transform("last")
    subdat = subdat.drop_duplicates(subset=['address'])
    subdat = subdat[(subdat["v_last_vol"]>min_transvol)]
    for _, apt in subdat.iterrows():
        folium.Marker(
        location = [apt["lat"], apt["lng"]],
        popup = round(apt[color_col],2),
        tooltip = apt["address"],
        icon = folium.Icon(color = apt["color"])).add_to(my_map)
    return(my_map)

# %% [markdown]
# * The interactive map below shows all apartment complexes whose transaction voloume were more than 50 for `last 3 months` as of last month.
# > * Only 7 APT complexes (mostly with low prices) were sold more than 50 times for last 3 months as of last month.
# * The colour of icons of this map shows the level of average prices of the apartment complexes.
# * The colour of icons generally shows (i) the level of  average prices of the apartment complexes or (ii) the level of transaction volume.
#
#  - Average price
#  > 1. beige: less than $\$500k$
#  > 2. orange:  from $\$500k$ to $\$1m$
#  > 3. red:  from $\$1m$ to $\$1.5m$
#  > 4. darkred: from $\$1.5m$ to $\$2m$
#  > 5. darkpurple: more than $\$2m$
#
#  - Transaction volume
#  > 1. beige: less than 10
#  > 2. orange:  from 10 to 20
#  > 3. red:  from 20 to 30
#  > 4. darkred: from 30 to 40
#  > 5. darkpurple: more than 40

# %%
my_map = initialize_map()
mapping(min_transvol =  50)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd676f788eb34cacd7f32d9293f5c938 {
#                     position: relative;
#                     width: 40.0%;
#                     height: 35.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd676f788eb34cacd7f32d9293f5c938&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fd676f788eb34cacd7f32d9293f5c938 = L.map(
#                 &quot;map_fd676f788eb34cacd7f32d9293f5c938&quot;,
#                 {
#                     center: [37.544294, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8b5f4cf8b8c6763093dae719fdb08fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fd676f788eb34cacd7f32d9293f5c938);
#
#
#             var marker_552ff4eb2c7bcda7026167b5a67c3ea0 = L.marker(
#                 [37.5276906, 127.1269046],
#                 {}
#             ).addTo(map_fd676f788eb34cacd7f32d9293f5c938);
#
#
#             var icon_9415e7b85f921cd4e265091738e8f0f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_552ff4eb2c7bcda7026167b5a67c3ea0.setIcon(icon_9415e7b85f921cd4e265091738e8f0f8);
#
#
#         var popup_d8d23cecb90912c091acd60e41082a05 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1269710a53cb4a080bc1f6a442586892 = $(`&lt;div id=&quot;html_1269710a53cb4a080bc1f6a442586892&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;23467.07&lt;/div&gt;`)[0];
#             popup_d8d23cecb90912c091acd60e41082a05.setContent(html_1269710a53cb4a080bc1f6a442586892);
#
#
#         marker_552ff4eb2c7bcda7026167b5a67c3ea0.bindPopup(popup_d8d23cecb90912c091acd60e41082a05)
#         ;
#
#
#
#
#             marker_552ff4eb2c7bcda7026167b5a67c3ea0.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 강동구 성내동 성내로 64 에스아이팰리스센트럴성내
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b6b3e46753241f598cab7dbc455c245d = L.marker(
#                 [37.4963942, 126.8359626],
#                 {}
#             ).addTo(map_fd676f788eb34cacd7f32d9293f5c938);
#
#
#             var icon_92b841107ccb3f5d7147bd8383549695 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b6b3e46753241f598cab7dbc455c245d.setIcon(icon_92b841107ccb3f5d7147bd8383549695);
#
#
#         var popup_182103af00345638e79963b308a705f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d29de813aaf393ff291254f55e2c800a = $(`&lt;div id=&quot;html_d29de813aaf393ff291254f55e2c800a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;42329.55&lt;/div&gt;`)[0];
#             popup_182103af00345638e79963b308a705f0.setContent(html_d29de813aaf393ff291254f55e2c800a);
#
#
#         marker_b6b3e46753241f598cab7dbc455c245d.bindPopup(popup_182103af00345638e79963b308a705f0)
#         ;
#
#
#
#
#             marker_b6b3e46753241f598cab7dbc455c245d.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 구로구 궁동 경인로15나길 65-4 궁동에스하임
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1770ee1c91f14f7499d93d3f4d7ea6c0 = L.marker(
#                 [37.449957, 126.9159965],
#                 {}
#             ).addTo(map_fd676f788eb34cacd7f32d9293f5c938);
#
#
#             var icon_85cbee36c654441aa3abe42c443c90a8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1770ee1c91f14f7499d93d3f4d7ea6c0.setIcon(icon_85cbee36c654441aa3abe42c443c90a8);
#
#
#         var popup_a906d48c42bc2c6830284475dd5027bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5bc22ba79b8a6e286db4c2821ad01722 = $(`&lt;div id=&quot;html_5bc22ba79b8a6e286db4c2821ad01722&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;60842.44&lt;/div&gt;`)[0];
#             popup_a906d48c42bc2c6830284475dd5027bf.setContent(html_5bc22ba79b8a6e286db4c2821ad01722);
#
#
#         marker_1770ee1c91f14f7499d93d3f4d7ea6c0.bindPopup(popup_a906d48c42bc2c6830284475dd5027bf)
#         ;
#
#
#
#
#             marker_1770ee1c91f14f7499d93d3f4d7ea6c0.bindTooltip(
#                 `&lt;div&gt;

# %% [markdown]
# * The interactive map below shows all apartment complexes whose transaction voloume were more than 50 for `last 6 months` as of last month.
# * The colour of icons of this map shows the level of average prices of the apartment complexes.

# %%
my_map = initialize_map()
mapping(nums="num_sales_last_6months", min_transvol =  50)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82ba84c16a6cb3c04f33cfd9d7525976 {
#                     position: relative;
#                     width: 40.0%;
#                     height: 35.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82ba84c16a6cb3c04f33cfd9d7525976&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_82ba84c16a6cb3c04f33cfd9d7525976 = L.map(
#                 &quot;map_82ba84c16a6cb3c04f33cfd9d7525976&quot;,
#                 {
#                     center: [37.544294, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49d3dd37c0420d85a6676415f4cf56e6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_82ba84c16a6cb3c04f33cfd9d7525976);
#
#
#             var marker_e03db700b7a6f2bc23797f0405ab7af5 = L.marker(
#                 [37.5276906, 127.1269046],
#                 {}
#             ).addTo(map_82ba84c16a6cb3c04f33cfd9d7525976);
#
#
#             var icon_822e0a3618084428c012f80b642de42f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e03db700b7a6f2bc23797f0405ab7af5.setIcon(icon_822e0a3618084428c012f80b642de42f);
#
#
#         var popup_a09fc754420c7d0f05414e201ccba4f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bb8ddba88cb644c7bc3f17d91d18d658 = $(`&lt;div id=&quot;html_bb8ddba88cb644c7bc3f17d91d18d658&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;23467.07&lt;/div&gt;`)[0];
#             popup_a09fc754420c7d0f05414e201ccba4f0.setContent(html_bb8ddba88cb644c7bc3f17d91d18d658);
#
#
#         marker_e03db700b7a6f2bc23797f0405ab7af5.bindPopup(popup_a09fc754420c7d0f05414e201ccba4f0)
#         ;
#
#
#
#
#             marker_e03db700b7a6f2bc23797f0405ab7af5.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 강동구 성내동 성내로 64 에스아이팰리스센트럴성내
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_87f0b0b9b2af01b1488b53763c5b43b5 = L.marker(
#                 [37.4963942, 126.8359626],
#                 {}
#             ).addTo(map_82ba84c16a6cb3c04f33cfd9d7525976);
#
#
#             var icon_68eeae471f25d28fd39c1d23d7dcfd5f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_87f0b0b9b2af01b1488b53763c5b43b5.setIcon(icon_68eeae471f25d28fd39c1d23d7dcfd5f);
#
#
#         var popup_a1166b3ecce021995d0bddf8d61b7a1a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_273cc258e3585741d603e7daeb731ab4 = $(`&lt;div id=&quot;html_273cc258e3585741d603e7daeb731ab4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;42329.55&lt;/div&gt;`)[0];
#             popup_a1166b3ecce021995d0bddf8d61b7a1a.setContent(html_273cc258e3585741d603e7daeb731ab4);
#
#
#         marker_87f0b0b9b2af01b1488b53763c5b43b5.bindPopup(popup_a1166b3ecce021995d0bddf8d61b7a1a)
#         ;
#
#
#
#
#             marker_87f0b0b9b2af01b1488b53763c5b43b5.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 구로구 궁동 경인로15나길 65-4 궁동에스하임
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1820a6165c1b0990ba926410e0150979 = L.marker(
#                 [37.449957, 126.9159965],
#                 {}
#             ).addTo(map_82ba84c16a6cb3c04f33cfd9d7525976);
#
#
#             var icon_b47e1887aeb38ed01c500c1e448ffca1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1820a6165c1b0990ba926410e0150979.setIcon(icon_b47e1887aeb38ed01c500c1e448ffca1);
#
#
#         var popup_2a4e83d638efb98c89a494fc659933e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_db90c49f942f81269a7d5b266c57b48e = $(`&lt;div id=&quot;html_db90c49f942f81269a7d5b266c57b48e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;60842.44&lt;/div&gt;`)[0];
#             popup_2a4e83d638efb98c89a494fc659933e7.setContent(html_db90c49f942f81269a7d5b266c57b48e);
#
#
#         marker_1820a6165c1b0990ba926410e0150979.bindPopup(popup_2a4e83d638efb98c89a494fc659933e7)
#         ;
#
#
#
#
#             marker_1820a6165c1b0990ba926410e0150979.bindTooltip(
#                 `&lt;div&gt;

# %% [markdown]
# * The interactive map below shows all apartment complexes whose transaction voloume were more than 50 for `last 12 months` as of last month.
# * The colour of icons of this map shows the level of average prices of the apartment complexes.

# %%
my_map = initialize_map()
mapping(nums="num_sales_last_12months", min_transvol =  50)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65079befdbd8d38e1f50ac8cacfba66c {
#                     position: relative;
#                     width: 40.0%;
#                     height: 35.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65079befdbd8d38e1f50ac8cacfba66c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_65079befdbd8d38e1f50ac8cacfba66c = L.map(
#                 &quot;map_65079befdbd8d38e1f50ac8cacfba66c&quot;,
#                 {
#                     center: [37.544294, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2088baa0d24beb14a41f0ddff84191fa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_65079befdbd8d38e1f50ac8cacfba66c);
#
#
#             var marker_2e706747c6d98362fa35a907c80cfee1 = L.marker(
#                 [37.4974576, 127.0653265],
#                 {}
#             ).addTo(map_65079befdbd8d38e1f50ac8cacfba66c);
#
#
#             var icon_6ee918563f17f0b107783ad065f7e6f1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkpurple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2e706747c6d98362fa35a907c80cfee1.setIcon(icon_6ee918563f17f0b107783ad065f7e6f1);
#
#
#         var popup_26f402c27049e3f62be0c8f08e160be4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ad8cdf19e2f7bc20038a9e735f6d8ec5 = $(`&lt;div id=&quot;html_ad8cdf19e2f7bc20038a9e735f6d8ec5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;234152.94&lt;/div&gt;`)[0];
#             popup_26f402c27049e3f62be0c8f08e160be4.setContent(html_ad8cdf19e2f7bc20038a9e735f6d8ec5);
#
#
#         marker_2e706747c6d98362fa35a907c80cfee1.bindPopup(popup_26f402c27049e3f62be0c8f08e160be4)
#         ;
#
#
#
#
#             marker_2e706747c6d98362fa35a907c80cfee1.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 강남구 대치동 삼성로 212 은마
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c36cbb4fe9b02f35c12bb341f0b8a7b0 = L.marker(
#                 [37.4846721, 127.0873935],
#                 {}
#             ).addTo(map_65079befdbd8d38e1f50ac8cacfba66c);
#
#
#             var icon_9eacb07d92c6641fc5c4b972960f8146 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c36cbb4fe9b02f35c12bb341f0b8a7b0.setIcon(icon_9eacb07d92c6641fc5c4b972960f8146);
#
#
#         var popup_5d41b4a1dfd4bf905fbf142d6a7813ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1abf6a5fa47e43256e1154eb924d102b = $(`&lt;div id=&quot;html_1abf6a5fa47e43256e1154eb924d102b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;102235.53&lt;/div&gt;`)[0];
#             popup_5d41b4a1dfd4bf905fbf142d6a7813ed.setContent(html_1abf6a5fa47e43256e1154eb924d102b);
#
#
#         marker_c36cbb4fe9b02f35c12bb341f0b8a7b0.bindPopup(popup_5d41b4a1dfd4bf905fbf142d6a7813ed)
#         ;
#
#
#
#
#             marker_c36cbb4fe9b02f35c12bb341f0b8a7b0.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 강남구 수서동 광평로19길 10 까치마을
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_55e61bc97ebd29270f5c13e582400f0a = L.marker(
#                 [37.5555874, 127.1475975],
#                 {}
#             ).addTo(map_65079befdbd8d38e1f50ac8cacfba66c);
#
#
#             var icon_9713dbabcc033f3a176a67bbbf27636e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_55e61bc97ebd29270f5c13e582400f0a.setIcon(icon_9713dbabcc033f3a176a67bbbf27636e);
#
#
#         var popup_a67b519fcb8b9fbb92331c734fb48e3b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_80a8bb59de984ee72511e76c1a3d2da5 = $(`&lt;div id=&quot;html_80a8bb59de984ee72511e76c1a3d2da5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;147728.26&lt;/div&gt;`)[0];
#             popup_a67b519fcb8b9fbb92331c734fb48e3b.setContent(html_80a8bb59de984ee72511e76c1a3d2da5);
#
#
#         marker_55e61bc97ebd29270f5c13e582400f0a.bindPopup(popup_a67b519fcb8b9fbb92331c734fb48e3b)
#         ;
#
#
#
#
#             marker_55e61bc97ebd29270f5c13e582400f0a.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시
