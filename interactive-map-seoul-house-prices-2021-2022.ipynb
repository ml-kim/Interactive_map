# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import folium 
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/seoul-apt-info/seoul_apt_info.csv

# %% [markdown]
# ### Intro
# * In this note, I create interactive maps using a data set that includes the prices of seoul apartments.
# > * These maps show the distribution of APT complexes whose transaction volumes are greater than certain levels and their average prices.
# * The package used: `panda` and `folium`

# %% [markdown]
# ### Import data
#
# * We use a data set that includes transaction prices of seoul apartments from Jan 2021 to May 2022 and their location information (latitude and longitude).

# %%
# import data
dat = pd.read_csv("../input/seoul-apt-info/seoul_apt_info.csv")
dat = dat.drop(["Unnamed: 0"], axis = 1)
dat.head()
# Out:
#                                 address   size  yearmon   price  floor  \
# 0  서울특별시 강남구 개포동 언주로 103 개포2차현대아파트(220)  77.75   202104  174000      9
# 1    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202105  195000      5
# 2    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202108  200000      3
# 3    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202109  220000      2
# 4    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202112  215000      3
#
#    const_year        lat         lng
# 0        1988  37.482630  127.051104
# 1        1987  37.476658  127.056909
# 2        1987  37.476658  127.056909
# 3        1987  37.476658  127.056909
# 4        1987  37.476658  127.056909

# %% [markdown]
# ### Process data
#
# 1. Calculate average price for each APT complex, year and month.
# 2. Calculate transaction volume for each APT complex and reference periods (for last 3months/6months/1year).

# %%
dat.dtypes
# Out:
# address        object
# size          float64
# yearmon         int64
# price           int64
# floor           int64
# const_year      int64
# lat           float64
# lng           float64
# dtype: object

# %%
def split_yr_mon(row):
    x = str(row["yearmon"])[0:4]
    x = int(x)
    return x
dat['year'] = dat.apply(lambda row: split_yr_mon(row), axis = 1)

# %%
dat.head()
# Out:
#                                 address   size  yearmon   price  floor  \
# 0  서울특별시 강남구 개포동 언주로 103 개포2차현대아파트(220)  77.75   202104  174000      9
# 1    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202105  195000      5
# 2    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202108  200000      3
# 3    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202109  220000      2
# 4    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202112  215000      3
#
#    const_year        lat         lng  year
# 0        1988  37.482630  127.051104  2021
# 1        1987  37.476658  127.056909  2021
# 2        1987  37.476658  127.056909  2021
# 3        1987  37.476658  127.056909  2021
# 4        1987  37.476658  127.056909  2021

# %%
def split_yr_mon2(row):
    x = str(row["yearmon"])[4:6]
    x = int(x)
    return x
dat['month'] = dat.apply(lambda row: split_yr_mon2(row), axis = 1)

# %%
dat.head()
# Out:
#                                 address   size  yearmon   price  floor  \
# 0  서울특별시 강남구 개포동 언주로 103 개포2차현대아파트(220)  77.75   202104  174000      9
# 1    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202105  195000      5
# 2    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202108  200000      3
# 3    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202109  220000      2
# 4    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97   202112  215000      3
#
#    const_year        lat         lng  year  month
# 0        1988  37.482630  127.051104  2021      4
# 1        1987  37.476658  127.056909  2021      5
# 2        1987  37.476658  127.056909  2021      8
# 3        1987  37.476658  127.056909  2021      9
# 4        1987  37.476658  127.056909  2021     12

# %%
# drop the existing column "yearmon"
dat.drop(["yearmon"], axis = 1, inplace = True)

# %%
# create yearmon column: 'year + month'
def create_yearmon(row):
    x= str(row["year"])+"-"+ str(row["month"])
    return x
dat['yearmon'] = dat.apply(lambda row: create_yearmon(row), axis = 1)
dat.head()
# Out:
#                                 address   size   price  floor  const_year  \
# 0  서울특별시 강남구 개포동 언주로 103 개포2차현대아파트(220)  77.75  174000      9        1988
# 1    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97  195000      5        1987
# 2    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97  200000      3        1987
# 3    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97  220000      2        1987
# 4    서울특별시 강남구 개포동 언주로 3 개포6차우성아파트1동~8동  79.97  215000      3        1987
#
#          lat         lng  year  month  yearmon
# 0  37.482630  127.051104  2021      4   2021-4
# 1  37.476658  127.056909  2021      5   2021-5
# 2  37.476658  127.056909  2021      8   2021-8
# 3  37.476658  127.056909  2021      9   2021-9
# 4  37.476658  127.056909  2021     12  2021-12

# %%
# calculate average transaction price for each apt complex
def calcul_avgprice(year0, month0, year1, month1):
    dat1= dat[(dat["year"]>=year0) & (dat["month"]>= month0)] 
    dat1 = dat1[(dat1["year"]<=year1) & (dat1["month"]<= month1)]
    dat1 = dat1.sort_values(by = ["address", "year", "month"])
    dat1["avgprice"]= dat1.groupby("address")["price"].transform("mean")
    return dat1


## calculate average transaction price for each apt complex and yearmon
# dat["avgprice"] = dat.groupby(["address", "yearmon"])["price"].transform("mean")
## calculate average transaction price for each apt complex and year
# dat["yr_avgprice"] = dat.groupby(["address", "year"])["price"].transform("mean")

# %%
# calculate house price return (monthly) for each apt complex
# calculate the number of months between transactions within same apt complex
def calcul_num_month(series):
    series = pd.to_datetime(series)
    series2 = (series - series.shift(1))/np.timedelta64(1, 'M')
    series2 = round(series2.astype(float))
    return series2
dat = dat.sort_values(by=['address','size','year', "month"])
aa=dat.groupby(['address','size'])["yearmon"].apply(calcul_num_month)
aa.index=dat.sort_values(by=['address','size','year', "month"]).index
dat['num_months']=aa
dat.loc[dat['num_months'] == 0, "num_months"] = 1

# %%
# calculate monthly house price return 
def calcul_monthly_r(series):
    series2 = series.pct_change()
    series2 = series2.astype(float)
    return series2
dat = dat.sort_values(by=['address','size','year', "month"])
aa=dat.groupby(['address','size'])["price"].apply(calcul_monthly_r)

aa.index=dat.sort_values(by=['address','size','year', "month"]).index
dat['returns']=aa
dat['monthly_return'] = dat["returns"]/dat['num_months']

dat = dat.sort_values(by = ["address", "year", "month"])
dat["monthly_r_per_complex"]= dat.groupby(["address", "year", "month"])["monthly_return"].transform("mean")

# %%
dat.head()
# Out:
#                             address   size   price  floor  const_year  \
# 5   서울특별시 강남구 개포동 개포로 264 개포래미안포레스트  74.66  245000      7        2020
# 7   서울특별시 강남구 개포동 개포로 264 개포래미안포레스트  49.92  180000      7        2020
# 6   서울특별시 강남구 개포동 개포로 264 개포래미안포레스트  59.92  198500     18        2020
# 8   서울특별시 강남구 개포동 개포로 264 개포래미안포레스트  59.92  205000      5        2020
# 11  서울특별시 강남구 개포동 개포로 264 개포래미안포레스트  49.92  185000      6        2020
#
#           lat         lng  year  month yearmon  num_months   returns  \
# 5   37.485149  127.059895  2021      1  2021-1         NaN       NaN
# 7   37.485149  127.059895  2021      5  2021-5         NaN       NaN
# 6   37.485149  127.059895  2021      5  2021-5         NaN       NaN
# 8   37.485149  127.059895  2021      5  2021-5         1.0  0.032746
# 11  37.485149  127.059895  2021      6  2021-6         1.0  0.027778
#
#     monthly_return  monthly_r_per_complex
# 5              NaN                    NaN
# 7              NaN               0.032746
# 6              NaN               0.032746
# 8         0.032746               0.032746
# 11        0.027778               0.017389

# %%
# calculate average return last 3 months/6 months/1year
def count_past_returns(series, intval = "90D"):
    series2 = series.copy()
    series2["yearmon"] = pd.to_datetime(series["yearmon"])
    series2.set_index("yearmon", inplace= True)
    ret = series2.rolling(intval, min_periods=1).mean()
    ret = ret.groupby(ret.index).transform('last')
    return ret
aa = dat.groupby('address')["yearmon", "monthly_r_per_complex"].apply(count_past_returns)
bb=dat.groupby('address')["yearmon", "monthly_r_per_complex"].apply(lambda series: count_past_returns(series, intval = "180D"))
cc=dat.groupby('address')["yearmon", "monthly_r_per_complex"].apply(lambda series: count_past_returns(series, intval = "365D"))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   if __name__ == "__main__":
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   # Remove the CWD from sys.path while we load stuff.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# put index
aa.index=dat.sort_values(by=['address','year', "month"]).index
bb.index=dat.sort_values(by=['address','year', "month"]).index
cc.index=dat.sort_values(by=['address','year', "month"]).index

dat['return_last_3months']=aa
dat['return_last_6months']=bb
dat['return_last_12months']=cc

# %%
# check the distribution of returns
dat['return_last_3months'].describe()
# Out:
# count    42013.000000
# mean         0.010611
# std          0.038177
# min         -0.488235
# 25%         -0.000934
# 50%          0.007601
# 75%          0.018994
# max          1.184300
# Name: return_last_3months, dtype: float64

# %%
# check the distribution of returns
dat['return_last_6months'].describe()
# Out:
# count    42346.000000
# mean         0.010455
# std          0.037457
# min         -0.488235
# 25%         -0.000195
# 50%          0.007594
# 75%          0.017954
# max          1.184300
# Name: return_last_6months, dtype: float64

# %%
# check the distribution of returns
dat['return_last_12months'].describe()
# Out:
# count    42516.000000
# mean         0.011025
# std          0.037528
# min         -0.488235
# 25%          0.000000
# 50%          0.008180
# 75%          0.018057
# max          1.184300
# Name: return_last_12months, dtype: float64

# %%
# calculate transaction volume for each apt complex and periods (3 months/6 months/1 year)
def count_past_sales(series, intval = "90D"):
    series2 = pd.to_datetime(series)
    sale_time = pd.Series(series2.index, index=series2, name='count_sales_this_month').sort_index() # exchange the positions of index and values
    count_sales = sale_time.rolling(intval, min_periods=1).count()
    count_sales = count_sales.groupby(count_sales.index.month).transform('last')
    return count_sales

# transaction volume for last 3 months/6months/1year
aa=dat.groupby('address')["yearmon"].apply(count_past_sales)
bb=dat.groupby('address')["yearmon"].apply(lambda series: count_past_sales(series, intval = "180D"))
cc=dat.groupby('address')["yearmon"].apply(lambda series: count_past_sales(series, intval = "365D"))

# put index
aa.index=dat.sort_values(by=['address','year', "month"]).index
bb.index=dat.sort_values(by=['address','year', "month"]).index
cc.index=dat.sort_values(by=['address','year', "month"]).index

dat['num_sales_last_3months']=aa
dat['num_sales_last_6months']=bb
dat['num_sales_last_12months']=cc

# %%
# drop observations with inappropriate location info
dat.drop(dat[dat["lng"].isnull() == True].index,axis = 0, inplace = True)
dat.drop(dat[dat["lat"].isnull() == True].index,axis = 0, inplace = True)

# %%
def assign_values(pr_col="avgprice"):
    if pr_col == "avgprice":
        return   50000,100000,150000,200000
    elif pr_col in ["num_sales_last_3months", "num_sales_last_6months", "num_sales_last_12months"]:
        return 10,20,30,40
    elif pr_col in ['return_last_3months', 'return_last_6months', 'return_last_12months']:
        return -0.01, 0, 0.01, 0.02
    
# create a column: "color" using price information
def colouring(row, pr_col="avgprice"):
    a1, a2, a3, a4 = assign_values(pr_col)
    if (row[pr_col] <= a1): # less than $500k 
        return "beige"
    elif (row[pr_col] > a1) and (row[pr_col] <= a2): # more than $500k and less than $1m
        return "orange"
    elif (row[pr_col] > a2) and (row[pr_col] <= a3): # more than $1m and less than $1.5m
        return "red"
    elif (row[pr_col] > a3) and (row[pr_col] <= a4): # more than $1.5m and less than $2m
        return "darkred"
    return "darkpurple"

# %% [markdown]
# ### Default setting for an interactive map

# %%
# define a map
def initialize_map():
    my_map = folium.Map(
        location = [37.544294, 127.0016985], 
        width="%40",
        height="%35",
        zoom_start= 12)
    return my_map

# %% [markdown]
# ### Create interactive maps

# %%
# Function for making a subdat set
def mapping(nums = "num_sales_last_3months", min_transvol = 10, color_col= "avgprice", yr0 = 2021, yr1 = 2022, mon0=1, mon1 = 5):
    # calculate avg prices per APT complex 
    dat = calcul_avgprice(yr0, mon0, yr1, mon1)
    # define color   
    dat["color"] = dat.apply(lambda row: colouring(row, pr_col = color_col), axis = 1)
    subdat = dat[(dat[nums]>min_transvol)]
    subdat = subdat.sort_values(by = ["address", "year", "month"])
    subdat["v_last_vol"] = subdat.groupby("address")[nums].transform("last")
    subdat = subdat.drop_duplicates(subset=['address'])
    subdat = subdat[(subdat["v_last_vol"]>min_transvol)]
    for _, apt in subdat.iterrows():
        folium.Marker(
        location = [apt["lat"], apt["lng"]],
        popup = round(apt[nums],2),
        tooltip = apt["address"],
        icon = folium.Icon(color = apt["color"])).add_to(my_map)
    return(my_map)

# %% [markdown]
# * The interactive map below shows all apartment complexes whose transaction voloume were more than 50 for `last 3 months` as of last month.
# > * Only 7 APT complexes (mostly with low prices) were sold more than 50 times for last 3 months as of last month.
# * The colour of icons of this map shows the level of average prices of the apartment complexes.
# * The colour of icons generally shows (i) the level of  average prices of the apartment complexes, (ii) the level of transaction volume or (iii) the level of return.
#
#  - Average price
#  > 1. beige: less than $\$500k$
#  > 2. orange:  from $\$500k$ to $\$1m$
#  > 3. red:  from $\$1m$ to $\$1.5m$
#  > 4. darkred: from $\$1.5m$ to $\$2m$
#  > 5. darkpurple: more than $\$2m$
#
#  - Transaction volume
#  > 1. beige: less than 10
#  > 2. orange:  from 10 to 20
#  > 3. red:  from 20 to 30
#  > 4. darkred: from 30 to 40
#  > 5. darkpurple: more than 40
#
#   - Average return
#  > 1. beige: less than -0.01
#  > 2. orange:  from -0.01 to 0
#  > 3. red:  from 0 to 0.01
#  > 4. darkred: from 0.01 to 0.02
#  > 5. darkpurple: more than 0.02

# %%
my_map = initialize_map()
mapping(min_transvol =  50)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3e0539f68afa11cc4aa11cb913a7b0c {
#                     position: relative;
#                     width: 40.0%;
#                     height: 35.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3e0539f68afa11cc4aa11cb913a7b0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f3e0539f68afa11cc4aa11cb913a7b0c = L.map(
#                 &quot;map_f3e0539f68afa11cc4aa11cb913a7b0c&quot;,
#                 {
#                     center: [37.544294, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aca8b311eaa5ea19cada52a65aefe6fa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f3e0539f68afa11cc4aa11cb913a7b0c);
#
#
#             var marker_593bed3af43829561ffd0d05d94b7591 = L.marker(
#                 [37.5276906, 127.1269046],
#                 {}
#             ).addTo(map_f3e0539f68afa11cc4aa11cb913a7b0c);
#
#
#             var icon_8d00bac6508f06c96d42c6c3bdeb0c10 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_593bed3af43829561ffd0d05d94b7591.setIcon(icon_8d00bac6508f06c96d42c6c3bdeb0c10);
#
#
#         var popup_6458fe819b09eb860cb6e2133079dc8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6c224cdabe9198abf50761cfbffa0b72 = $(`&lt;div id=&quot;html_6c224cdabe9198abf50761cfbffa0b72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;80.0&lt;/div&gt;`)[0];
#             popup_6458fe819b09eb860cb6e2133079dc8a.setContent(html_6c224cdabe9198abf50761cfbffa0b72);
#
#
#         marker_593bed3af43829561ffd0d05d94b7591.bindPopup(popup_6458fe819b09eb860cb6e2133079dc8a)
#         ;
#
#
#
#
#             marker_593bed3af43829561ffd0d05d94b7591.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 강동구 성내동 성내로 64 에스아이팰리스센트럴성내
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cde47e91841d50e4d2e5d318efe2f31b = L.marker(
#                 [37.4963942, 126.8359626],
#                 {}
#             ).addTo(map_f3e0539f68afa11cc4aa11cb913a7b0c);
#
#
#             var icon_83715ab309b4ab86659c441d257da4b6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cde47e91841d50e4d2e5d318efe2f31b.setIcon(icon_83715ab309b4ab86659c441d257da4b6);
#
#
#         var popup_94e5d7f40c9323acd1789f1dd275eded = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_58f177ccf9ca22b1aaa0bbede93fb1e3 = $(`&lt;div id=&quot;html_58f177ccf9ca22b1aaa0bbede93fb1e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;88.0&lt;/div&gt;`)[0];
#             popup_94e5d7f40c9323acd1789f1dd275eded.setContent(html_58f177ccf9ca22b1aaa0bbede93fb1e3);
#
#
#         marker_cde47e91841d50e4d2e5d318efe2f31b.bindPopup(popup_94e5d7f40c9323acd1789f1dd275eded)
#         ;
#
#
#
#
#             marker_cde47e91841d50e4d2e5d318efe2f31b.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 구로구 궁동 경인로15나길 65-4 궁동에스하임
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dd3c8ead740f80f57c2dab1afac6735f = L.marker(
#                 [37.449957, 126.9159965],
#                 {}
#             ).addTo(map_f3e0539f68afa11cc4aa11cb913a7b0c);
#
#
#             var icon_4f4b53853c9a5384be98842e57e2b087 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dd3c8ead740f80f57c2dab1afac6735f.setIcon(icon_4f4b53853c9a5384be98842e57e2b087);
#
#
#         var popup_ec734fe3514dd85006c945bee9316e82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_14b9bbd6745be070c06f199b63892a22 = $(`&lt;div id=&quot;html_14b9bbd6745be070c06f199b63892a22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;52.0&lt;/div&gt;`)[0];
#             popup_ec734fe3514dd85006c945bee9316e82.setContent(html_14b9bbd6745be070c06f199b63892a22);
#
#
#         marker_dd3c8ead740f80f57c2dab1afac6735f.bindPopup(popup_ec734fe3514dd85006c945bee9316e82)
#         ;
#
#
#
#
#             marker_dd3c8ead740f80f57c2dab1afac6735f.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 금천

# %% [markdown]
# * The interactive map below shows all apartment complexes whose transaction voloume were more than 50 for `last 3 months` as of last month.
# > * Only 7 APT complexes (mostly with low prices) were sold more than 50 times for last 3 months as of last month.
# * The colour of icons of this map shows the level of returns (last 3 months) of apartment complexes.

# %%
my_map = initialize_map()
mapping(min_transvol =  50, color_col = 'return_last_3months')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4219df989a271a74e13075263ff5a109 {
#                     position: relative;
#                     width: 40.0%;
#                     height: 35.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4219df989a271a74e13075263ff5a109&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4219df989a271a74e13075263ff5a109 = L.map(
#                 &quot;map_4219df989a271a74e13075263ff5a109&quot;,
#                 {
#                     center: [37.544294, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16b168c8f7d7a2266a0518033cbdc82d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4219df989a271a74e13075263ff5a109);
#
#
#             var marker_aee047cd84970ab77f2115bc74bf939b = L.marker(
#                 [37.5276906, 127.1269046],
#                 {}
#             ).addTo(map_4219df989a271a74e13075263ff5a109);
#
#
#             var icon_ec3a5e23697b4d91bde36f6e0b9570c5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aee047cd84970ab77f2115bc74bf939b.setIcon(icon_ec3a5e23697b4d91bde36f6e0b9570c5);
#
#
#         var popup_068df013878e3cb58f20ffcc1c6edc35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8d8f9c5edf304e9291ee1993b95c0dae = $(`&lt;div id=&quot;html_8d8f9c5edf304e9291ee1993b95c0dae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;80.0&lt;/div&gt;`)[0];
#             popup_068df013878e3cb58f20ffcc1c6edc35.setContent(html_8d8f9c5edf304e9291ee1993b95c0dae);
#
#
#         marker_aee047cd84970ab77f2115bc74bf939b.bindPopup(popup_068df013878e3cb58f20ffcc1c6edc35)
#         ;
#
#
#
#
#             marker_aee047cd84970ab77f2115bc74bf939b.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 강동구 성내동 성내로 64 에스아이팰리스센트럴성내
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d06936d0da0cac1b61f3cc5ce3acf169 = L.marker(
#                 [37.4963942, 126.8359626],
#                 {}
#             ).addTo(map_4219df989a271a74e13075263ff5a109);
#
#
#             var icon_65dfa5cc30e452a09e9eb9d640d96c23 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d06936d0da0cac1b61f3cc5ce3acf169.setIcon(icon_65dfa5cc30e452a09e9eb9d640d96c23);
#
#
#         var popup_1debc1a525c9f6341e1af8f7f8f25b89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d79a725eaa52b04e285a98bef077f003 = $(`&lt;div id=&quot;html_d79a725eaa52b04e285a98bef077f003&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;88.0&lt;/div&gt;`)[0];
#             popup_1debc1a525c9f6341e1af8f7f8f25b89.setContent(html_d79a725eaa52b04e285a98bef077f003);
#
#
#         marker_d06936d0da0cac1b61f3cc5ce3acf169.bindPopup(popup_1debc1a525c9f6341e1af8f7f8f25b89)
#         ;
#
#
#
#
#             marker_d06936d0da0cac1b61f3cc5ce3acf169.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 구로구 궁동 경인로15나길 65-4 궁동에스하임
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a232f0b163ea7a892ad4c0c07fab0332 = L.marker(
#                 [37.449957, 126.9159965],
#                 {}
#             ).addTo(map_4219df989a271a74e13075263ff5a109);
#
#
#             var icon_a77c4d8af9fa358dc3bafe92230e7ced = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a232f0b163ea7a892ad4c0c07fab0332.setIcon(icon_a77c4d8af9fa358dc3bafe92230e7ced);
#
#
#         var popup_bf36a8fa2076b4fc182cce9a919e9827 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6bb0c7e3bf39c1d2ef73ae4edce2f3c2 = $(`&lt;div id=&quot;html_6bb0c7e3bf39c1d2ef73ae4edce2f3c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;52.0&lt;/div&gt;`)[0];
#             popup_bf36a8fa2076b4fc182cce9a919e9827.setContent(html_6bb0c7e3bf39c1d2ef73ae4edce2f3c2);
#
#
#         marker_a232f0b163ea7a892ad4c0c07fab0332.bindPopup(popup_bf36a8fa2076b4fc182cce9a919e9827)
#         ;
#
#
#
#
#             marker_a232f0b163ea7a892ad4c0c07fab0332.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 금천구

# %% [markdown]
# * The interactive map below shows all apartment complexes whose transaction voloume were more than 50 for `last 6 months` as of last month.
# * The colour of icons of this map shows the level of average prices of the apartment complexes.

# %%
my_map = initialize_map()
mapping(nums="num_sales_last_6months", min_transvol =  50)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d07ea1fe32ca3af279e043346946b5b {
#                     position: relative;
#                     width: 40.0%;
#                     height: 35.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d07ea1fe32ca3af279e043346946b5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4d07ea1fe32ca3af279e043346946b5b = L.map(
#                 &quot;map_4d07ea1fe32ca3af279e043346946b5b&quot;,
#                 {
#                     center: [37.544294, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f50f7539bc93641657163a85b600ce0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4d07ea1fe32ca3af279e043346946b5b);
#
#
#             var marker_238e2deee0fc078a346ab067868bbf66 = L.marker(
#                 [37.5276906, 127.1269046],
#                 {}
#             ).addTo(map_4d07ea1fe32ca3af279e043346946b5b);
#
#
#             var icon_fdc9d6ffe7e140a05ebf7f6f30a51473 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_238e2deee0fc078a346ab067868bbf66.setIcon(icon_fdc9d6ffe7e140a05ebf7f6f30a51473);
#
#
#         var popup_8424f48c673fbf17817d9ac14f67d870 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_598537d8a88decb2d81eb26bbe477291 = $(`&lt;div id=&quot;html_598537d8a88decb2d81eb26bbe477291&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;80.0&lt;/div&gt;`)[0];
#             popup_8424f48c673fbf17817d9ac14f67d870.setContent(html_598537d8a88decb2d81eb26bbe477291);
#
#
#         marker_238e2deee0fc078a346ab067868bbf66.bindPopup(popup_8424f48c673fbf17817d9ac14f67d870)
#         ;
#
#
#
#
#             marker_238e2deee0fc078a346ab067868bbf66.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 강동구 성내동 성내로 64 에스아이팰리스센트럴성내
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6c866ed83e68dc1a98c5f9f6afead6f2 = L.marker(
#                 [37.4963942, 126.8359626],
#                 {}
#             ).addTo(map_4d07ea1fe32ca3af279e043346946b5b);
#
#
#             var icon_cd5e0fd88e873a487c8d5e7fcfc873df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6c866ed83e68dc1a98c5f9f6afead6f2.setIcon(icon_cd5e0fd88e873a487c8d5e7fcfc873df);
#
#
#         var popup_5c514991d4a3d9025ff12c570d6e35de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_01a856529f1bf0ab78c23cf369fbda38 = $(`&lt;div id=&quot;html_01a856529f1bf0ab78c23cf369fbda38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;88.0&lt;/div&gt;`)[0];
#             popup_5c514991d4a3d9025ff12c570d6e35de.setContent(html_01a856529f1bf0ab78c23cf369fbda38);
#
#
#         marker_6c866ed83e68dc1a98c5f9f6afead6f2.bindPopup(popup_5c514991d4a3d9025ff12c570d6e35de)
#         ;
#
#
#
#
#             marker_6c866ed83e68dc1a98c5f9f6afead6f2.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 구로구 궁동 경인로15나길 65-4 궁동에스하임
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_51b24052c18f922d60c4fbfdffc51e7a = L.marker(
#                 [37.449957, 126.9159965],
#                 {}
#             ).addTo(map_4d07ea1fe32ca3af279e043346946b5b);
#
#
#             var icon_12fc51264a541270ee6604571ca5374f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_51b24052c18f922d60c4fbfdffc51e7a.setIcon(icon_12fc51264a541270ee6604571ca5374f);
#
#
#         var popup_6faba2776ffd26ea787b87e7c705c88a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f2d00fd8fdc935271b60d918bdb15e66 = $(`&lt;div id=&quot;html_f2d00fd8fdc935271b60d918bdb15e66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;54.0&lt;/div&gt;`)[0];
#             popup_6faba2776ffd26ea787b87e7c705c88a.setContent(html_f2d00fd8fdc935271b60d918bdb15e66);
#
#
#         marker_51b24052c18f922d60c4fbfdffc51e7a.bindPopup(popup_6faba2776ffd26ea787b87e7c705c88a)
#         ;
#
#
#
#
#             marker_51b24052c18f922d60c4fbfdffc51e7a.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 금천

# %% [markdown]
# * The interactive map below shows all apartment complexes whose transaction voloume were more than 50 for `last 12 months` as of last month.
# * The colour of icons of this map shows the level of average prices of the apartment complexes.

# %%
my_map = initialize_map()
mapping(nums="num_sales_last_12months", min_transvol =  50)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fe3e9939f1f0b9dd46fd255bd89e35c {
#                     position: relative;
#                     width: 40.0%;
#                     height: 35.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fe3e9939f1f0b9dd46fd255bd89e35c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3fe3e9939f1f0b9dd46fd255bd89e35c = L.map(
#                 &quot;map_3fe3e9939f1f0b9dd46fd255bd89e35c&quot;,
#                 {
#                     center: [37.544294, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04530039691e3813c22087252ddce9b5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3fe3e9939f1f0b9dd46fd255bd89e35c);
#
#
#             var marker_fb21e06084412b574fa7730a5bdced79 = L.marker(
#                 [37.4974576, 127.0653265],
#                 {}
#             ).addTo(map_3fe3e9939f1f0b9dd46fd255bd89e35c);
#
#
#             var icon_22c62e9797885e7f3ebe0db50996781d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkpurple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fb21e06084412b574fa7730a5bdced79.setIcon(icon_22c62e9797885e7f3ebe0db50996781d);
#
#
#         var popup_dd35529f2058b2a1452070b34fd8e0be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_76db33cda0988bc1b0dcb4f1d1ba18a7 = $(`&lt;div id=&quot;html_76db33cda0988bc1b0dcb4f1d1ba18a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;55.0&lt;/div&gt;`)[0];
#             popup_dd35529f2058b2a1452070b34fd8e0be.setContent(html_76db33cda0988bc1b0dcb4f1d1ba18a7);
#
#
#         marker_fb21e06084412b574fa7730a5bdced79.bindPopup(popup_dd35529f2058b2a1452070b34fd8e0be)
#         ;
#
#
#
#
#             marker_fb21e06084412b574fa7730a5bdced79.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 강남구 대치동 삼성로 212 은마
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_979fbd71af9a626dd0bb564d28a5d4b0 = L.marker(
#                 [37.4846721, 127.0873935],
#                 {}
#             ).addTo(map_3fe3e9939f1f0b9dd46fd255bd89e35c);
#
#
#             var icon_8e628e40b4846484239df415c7b89d5a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_979fbd71af9a626dd0bb564d28a5d4b0.setIcon(icon_8e628e40b4846484239df415c7b89d5a);
#
#
#         var popup_86dfb9c88076b73f41fbb65648c53def = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6ce5101c42194c7fe9f150a60397baae = $(`&lt;div id=&quot;html_6ce5101c42194c7fe9f150a60397baae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;57.0&lt;/div&gt;`)[0];
#             popup_86dfb9c88076b73f41fbb65648c53def.setContent(html_6ce5101c42194c7fe9f150a60397baae);
#
#
#         marker_979fbd71af9a626dd0bb564d28a5d4b0.bindPopup(popup_86dfb9c88076b73f41fbb65648c53def)
#         ;
#
#
#
#
#             marker_979fbd71af9a626dd0bb564d28a5d4b0.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 강남구 수서동 광평로19길 10 까치마을
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2583713e6dda899040d3e7fcbfd9c2c2 = L.marker(
#                 [37.5555874, 127.1475975],
#                 {}
#             ).addTo(map_3fe3e9939f1f0b9dd46fd255bd89e35c);
#
#
#             var icon_4a9042102090e950d760941ccccc73e5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2583713e6dda899040d3e7fcbfd9c2c2.setIcon(icon_4a9042102090e950d760941ccccc73e5);
#
#
#         var popup_9914f5edd05ed12cc17a738a54f68b7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0752a71c8481f8b4bc1f30def691e95f = $(`&lt;div id=&quot;html_0752a71c8481f8b4bc1f30def691e95f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;63.0&lt;/div&gt;`)[0];
#             popup_9914f5edd05ed12cc17a738a54f68b7d.setContent(html_0752a71c8481f8b4bc1f30def691e95f);
#
#
#         marker_2583713e6dda899040d3e7fcbfd9c2c2.bindPopup(popup_9914f5edd05ed12cc17a738a54f68b7d)
#         ;
#
#
#
#
#             marker_2583713e6dda899040d3e7fcbfd9c2c2.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 강동구 고덕동 고덕로 33
